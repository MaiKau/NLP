# %% [markdown]
# <h1><center>BERT</center></h1>

# %%
# bert-serving-start -model_dir D:\BM25_BERT\chinese_L-12_H-768_A-12/ -num_worker=2

from bert_serving.client import BertClient
import numpy as np
from pandas import DataFrame
import pandas as pd

class SimilarModel:
    
    #client位置
    def __init__(self):
        self.bert_client = BertClient(ip='127.0.0.1')
    
    #close
    def close_bert(self):
        self.bert_client .close()
    
    #向量化
    def get_sentence_vec(self,sentence):
        return self.bert_client .encode([sentence])[0]
    
    #相似度
    def cos_similar(self,sen_a_vec,sen_b_vec):
        vector_a=np.mat(sen_a_vec)
        vector_b=np.mat(sen_b_vec)
        num=float(vector_a*vector_b.T)
        denom=np.linalg.norm(vector_a)*np.linalg.norm(vector_b)
        cos=num/denom
        return cos

if __name__=='__main__':
    
    #
    condinates= [
    "光泉鮮豆漿",
    "（好５）蔓越莓綜合果汁",
    "義美無加糖厚濃高纖黑豆奶",
    "大吸館寒天冬瓜檸檬ＱＱ",
    "咖啡伴黑糖奶茶",
    "統一陽光低糖高纖豆漿",
    "冷泡茶冷萃綠茶",
    "原萃冷萃金萱烏龍",
    "原萃凍頂青茶",
    "ＵＣＣ藍山克里曼綜合黑咖啡",
    "愛之味分解茶",
    "（選）愛之味沖繩島黑八寶禮盒",
    "三矢不知火柑橘蘇打",
    "純喫茶檸檬紅茶６５０ｍｌ",
    "鮮摘果園芭樂綜合果汁",
    "黑丸仙草甘茶",
    "貝納頌經典榛果風味拿鐵",
    "ＦＭＣ紅拿鐵",
    "小文輕烏龍奶",
    "每朝健康無糖熟藏紅茶",
    "烏龍綠茶",
    "泰山綠豆椰果",
    "蜜香歐蕾",
    "光泉黑芝麻鮮豆漿",
    "四季春青茶",
    "橘子葡萄柚風味飲",
    "黑糖紅玉薑茶（溫罐）",
    "伯朗曼特寧咖啡",
    "Ｃ＆Ｃ乳酸菌氣泡飲",
    "可口可樂蘋果口味",
    "Ｃｈｅｅｒｓ黃金柚氣泡水",
    "茉莉茶園茉香柚茶",
    "鮮榨蘋果汁",
    "左岸咖啡館昂列咖啡",
    "純萃喝重乳拿鐵",
    "義美古早傳統豆奶",
    "光泉燕麥高纖豆漿",
    "一日水果１００％蘋果汁",
    "伊藤園濃味綠茶",
    "貝納頌經典黑咖啡",
    "職人無糖冰咖啡９１０",
    "義美古早傳統無糖豆奶",
    "古早味紅茶",
    "純萃喝綠茶歐蕾",
    "一日蔬果１００％蔬果汁",
    "ＦＭＣ金萱二十七",
    "ＷＯＮＤＡ咖啡歐蕾",
    "雀巢雪梨茶",
    "伯朗冷萃無糖拿鐵",
    "寶礦力水得ｉｏｎｗａｔｅｒ",
    "蠻牛能量飲料",
    "健酪含鈣飲料",
    "台灣農林日月紅茶",
    "ＦＭＣ荔枝蘋果烏龍茶",
    "波蜜蔬果汁低卡",
    "貝納頌鑑賞級極品咖啡",
    "貝納頌經典拿鐵",
    "義美古早傳統無糖豆奶１Ｌ",
    "立頓原味奶茶",
    "珍煮丹黑糖鮮奶茶",
    "純萃喝紅茶歐蕾",
    "雙倍奶茶",
    "喬亞滴濾無糖黑咖啡",
    "藍山咖啡（６入）",
    "味丹冬瓜茶",
    "午后時光重乳可可奶茶",
    "仙草蜜夏季限定版",
    "飲冰室茶集綠奶茶",
    "黑丸仙草奶茶",
    "原萃日式焙茶",
    "原萃冷萃日式深蒸綠茶",
    "伯朗咖啡禮盒",
    "藍山咖啡禮盒",
    "三矢甘王草莓蘇打",
    "三矢海鹽蘇打",
    "光泉巧克力牛奶ＴＰ",
    "舒味思伯爵紅茶風味氣泡水",
    "芒果冰茶",
    "波蜜果菜汁",
    "ＦＭＣ楊枝甘露",
    "ＦＭＣ鮮榨金鑽鳳梨原汁",
    "午后時光嚴選曼特寧咖啡",
    "光泉薏仁糙米漿",
    "ＦＭＣ尼爾吉里藍山莊園紅茶",
    "義美古早傳統豆奶１Ｌ",
    "（選）悅氏礦泉茶品綠茶２Ｌ",
    "義美低糖高纖全豆豆奶",
    "檸檬蜂蜜水",
    "蜂蜜黑木耳露",
    "光泉無加糖濃豆漿",
    "伯朗冷萃無糖黑咖啡",
    "激浪冰晶檸檬風味汽水",
    "可口可樂巧克力咖啡汽水",
    "掠奪者能量飲料",
    "Ｃｈｅｅｒｓ檸檬氣泡水",
    "芭樂檸檬青茶",
    "純喫茶紅茶６５０ｍｌ",
    "ＦＭＣ綠拿鐵",
    "職人加糖冰咖啡９１０",
    "光泉無加糖黑豆漿"    
    ]
    sentence_a='冰咖啡'
    bert_client=SimilarModel()
    max_cos_similar=0
    most_similar_sentence=''
    count=-1
    list_vec=[]
    list_name=[]
    
    #逐項轉向量
    for sentence_b in condinates:
        count=count+1
        sentence_a_vec=bert_client.get_sentence_vec(sentence_a)
        sentence_b_vec=bert_client.get_sentence_vec(sentence_b)
        cos_similar=bert_client.cos_similar(sentence_a_vec,sentence_b_vec)
        list_vec.append(cos_similar)
        list_name.append(condinates[count])
        print(cos_similar,condinates[count])
        
        #比大小
        if cos_similar>max_cos_similar:
            max_cos_similar=cos_similar
            most_similar_sentence=sentence_b
    print("-----------------------------------------------------------------------------------------------")
    print('與「'+sentence_a+'」最相近的產品:',most_similar_sentence,max_cos_similar)
    print("-----------------------------------------------------------------------------------------------")
    bert_client.close_bert()

#df sort
dict_df={"list_vec":list_vec,
         "list_name":list_name
        }
data=DataFrame(dict_df)
sult=data.sort_values(by=['list_vec'],ascending=False)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(sult)
# Out:
# 0.8510425597952905 光泉鮮豆漿
# 0.8405989436817014 （好５）蔓越莓綜合果汁
# 0.8166138840122512 義美無加糖厚濃高纖黑豆奶
# 0.8392571235873889 大吸館寒天冬瓜檸檬ＱＱ
# 0.9086584003147149 咖啡伴黑糖奶茶
# 0.8176699339993789 統一陽光低糖高纖豆漿
# 0.8688643923505474 冷泡茶冷萃綠茶
# 0.8188184366375734 原萃冷萃金萱烏龍
# 0.8395733120666223 原萃凍頂青茶
# 0.8673167243870514 ＵＣＣ藍山克里曼綜合黑咖啡
# 0.8477591044793978 愛之味分解茶
# 0.7932029799816879 （選）愛之味沖繩島黑八寶禮盒
# 0.8147305381169381 三矢不知火柑橘蘇打
# 0.8219104004010441 純喫茶檸檬紅茶６５０ｍｌ
# 0.827796683950169 鮮摘果園芭樂綜合果汁
# 0.8343080406893001 黑丸仙草甘茶
# 0.8348825852740767 貝納頌經典榛果風味拿鐵
# 0.8573629482640344 ＦＭＣ紅拿鐵
# 0.8666576092819146 小文輕烏龍奶
# 0.8368572431543999 每朝健康無糖熟藏紅茶
# 0.871888573167606 烏龍綠茶
# 0.8255438775505807 泰山綠豆椰果
# 0.8467952648787196 蜜香歐蕾
# 0.8472215532410515 光泉黑芝麻鮮豆漿
# 0.8530406887233626 四季春青茶
# 0.8302138841231579 橘子葡萄柚風味飲
# 0.8387609161356099 黑糖紅玉薑茶（溫罐）
# 0.868744705895295 伯朗曼特寧咖啡
# 0.7967807680941228 Ｃ＆Ｃ乳酸菌氣泡飲
# 0.8037241786296909 可口可樂蘋果口味
# 0.7944072153228164 Ｃｈｅｅｒｓ黃金柚氣泡水
# 0.8222885685428782 茉莉茶園茉香柚茶
# 0.871558961784676 鮮榨蘋果汁
# ...

# %% [markdown]
# <h1><center>BM25</center></h1>

# %%
import jieba
from rank_bm25 import BM25Okapi
corpus = [
    "光泉鮮豆漿",
    "（好５）蔓越莓綜合果汁",
    "義美無加糖厚濃高纖黑豆奶",
    "大吸館寒天冬瓜檸檬ＱＱ",
    "咖啡伴黑糖奶茶",
    "統一陽光低糖高纖豆漿",
    "冷泡茶冷萃綠茶",
    "原萃冷萃金萱烏龍",
    "原萃凍頂青茶",
    "ＵＣＣ藍山克里曼綜合黑咖啡",
    "愛之味分解茶",
    "（選）愛之味沖繩島黑八寶禮盒",
    "三矢不知火柑橘蘇打",
    "純喫茶檸檬紅茶６５０ｍｌ",
    "鮮摘果園芭樂綜合果汁",
    "黑丸仙草甘茶",
    "貝納頌經典榛果風味拿鐵",
    "ＦＭＣ紅拿鐵",
    "小文輕烏龍奶",
    "每朝健康無糖熟藏紅茶",
    "烏龍綠茶",
    "泰山綠豆椰果",
    "蜜香歐蕾",
    "光泉黑芝麻鮮豆漿",
    "四季春青茶",
    "橘子葡萄柚風味飲",
    "黑糖紅玉薑茶（溫罐）",
    "伯朗曼特寧咖啡",
    "Ｃ＆Ｃ乳酸菌氣泡飲",
    "可口可樂蘋果口味",
    "Ｃｈｅｅｒｓ黃金柚氣泡水",
    "茉莉茶園茉香柚茶",
    "鮮榨蘋果汁",
    "左岸咖啡館昂列咖啡",
    "純萃喝重乳拿鐵",
    "義美古早傳統豆奶",
    "光泉燕麥高纖豆漿",
    "一日水果１００％蘋果汁",
    "伊藤園濃味綠茶",
    "貝納頌經典黑咖啡",
    "職人無糖冰咖啡９１０",
    "義美古早傳統無糖豆奶",
    "古早味紅茶",
    "純萃喝綠茶歐蕾",
    "一日蔬果１００％蔬果汁",
    "ＦＭＣ金萱二十七",
    "ＷＯＮＤＡ咖啡歐蕾",
    "雀巢雪梨茶",
    "伯朗冷萃無糖拿鐵",
    "寶礦力水得ｉｏｎｗａｔｅｒ",
    "蠻牛能量飲料",
    "健酪含鈣飲料",
    "台灣農林日月紅茶",
    "ＦＭＣ荔枝蘋果烏龍茶",
    "波蜜蔬果汁低卡",
    "貝納頌鑑賞級極品咖啡",
    "貝納頌經典拿鐵",
    "義美古早傳統無糖豆奶１Ｌ",
    "立頓原味奶茶",
    "珍煮丹黑糖鮮奶茶",
    "純萃喝紅茶歐蕾",
    "雙倍奶茶",
    "喬亞滴濾無糖黑咖啡",
    "藍山咖啡（６入）",
    "味丹冬瓜茶",
    "午后時光重乳可可奶茶",
    "仙草蜜夏季限定版",
    "飲冰室茶集綠奶茶",
    "黑丸仙草奶茶",
    "原萃日式焙茶",
    "原萃冷萃日式深蒸綠茶",
    "伯朗咖啡禮盒",
    "藍山咖啡禮盒",
    "三矢甘王草莓蘇打",
    "三矢海鹽蘇打",
    "光泉巧克力牛奶ＴＰ",
    "舒味思伯爵紅茶風味氣泡水",
    "芒果冰茶",
    "波蜜果菜汁",
    "ＦＭＣ楊枝甘露",
    "ＦＭＣ鮮榨金鑽鳳梨原汁",
    "午后時光嚴選曼特寧咖啡",
    "光泉薏仁糙米漿",
    "ＦＭＣ尼爾吉里藍山莊園紅茶",
    "義美古早傳統豆奶１Ｌ",
    "（選）悅氏礦泉茶品綠茶２Ｌ",
    "義美低糖高纖全豆豆奶",
    "檸檬蜂蜜水",
    "蜂蜜黑木耳露",
    "光泉無加糖濃豆漿",
    "伯朗冷萃無糖黑咖啡",
    "激浪冰晶檸檬風味汽水",
    "可口可樂巧克力咖啡汽水",
    "掠奪者能量飲料",
    "Ｃｈｅｅｒｓ檸檬氣泡水",
    "芭樂檸檬青茶",
    "純喫茶紅茶６５０ｍｌ",
    "ＦＭＣ綠拿鐵",
    "職人加糖冰咖啡９１０",
    "光泉無加糖黑豆漿"   
]
tokenized_corpus = [list(jieba.cut(doc)) for doc in corpus]
bm25 = BM25Okapi(tokenized_corpus)

query = "冰咖啡"

tokenized_query = list(jieba.cut(query))
doc_scores = bm25.get_scores(tokenized_query)
top1 = bm25.get_top_n(tokenized_query,corpus,n=1)

# print("斷詞結果:",tokenized_corpus)

list_doc_scores = list(doc_scores)
list_corpus = list(corpus)

#df sort
dict_df2={"doc_scores":list_doc_scores,
         "corpu":list_corpus
        }
data2=DataFrame(dict_df2)
sult2=data2.sort_values(by=['doc_scores'],ascending=False)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print("-------------------------------------------------------------------------------------------------------------------------")
    print('與「'+query+'」最相近的產品:',top1,sult2['doc_scores'].max())
    print("-------------------------------------------------------------------------------------------------------------------------")
    print(sult2)
# Out:
# -------------------------------------------------------------------------------------------------------------------------
# 與「冰咖啡」最相近的產品: ['職人無糖冰咖啡９１０'] 4.3186966572586165
# -------------------------------------------------------------------------------------------------------------------------
#     doc_scores           corpu
# 98    4.318697      職人加糖冰咖啡９１０
# 40    4.318697      職人無糖冰咖啡９１０
# 33    2.441667       左岸咖啡館昂列咖啡
# 72    1.942321          藍山咖啡禮盒
# 71    1.942321          伯朗咖啡禮盒
# 62    1.741483       喬亞滴濾無糖黑咖啡
# 27    1.741483         伯朗曼特寧咖啡
# 39    1.741483        貝納頌經典黑咖啡
# 55    1.741483      貝納頌鑑賞級極品咖啡
# 4     1.741483         咖啡伴黑糖奶茶
# 92    1.578287     可口可樂巧克力咖啡汽水
# 90    1.578287       伯朗冷萃無糖黑咖啡
# 81    1.578287     午后時光嚴選曼特寧咖啡
# 63    1.443057        藍山咖啡（６入）
# 46    1.329171       ＷＯＮＤＡ咖啡歐蕾
# 9     1.231947   ＵＣＣ藍山克里曼綜合黑咖啡
# 64    0.000000           味丹冬瓜茶
# 65    0.000000      午后時光重乳可可奶茶
# 59    0.000000        珍煮丹黑糖鮮奶茶
# 73    0.000000        三矢甘王草莓蘇打
# ...
