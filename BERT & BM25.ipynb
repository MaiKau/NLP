# %% [markdown]
# <h1><center>BERT</center></h1>

# %%
# bert-serving-start -model_dir D:\BM25_BERT\chinese_L-12_H-768_A-12/ -num_worker=2

from bert_serving.client import BertClient
import numpy as np
from pandas import DataFrame
import pandas as pd

class SimilarModel:
    
    #client位置
    def __init__(self):
        self.bert_client = BertClient(ip='127.0.0.1')
    
    #close
    def close_bert(self):
        self.bert_client .close()
    
    #向量化
    def get_sentence_vec(self,sentence):
        return self.bert_client .encode([sentence])[0]
    
    #相似度
    def cos_similar(self,sen_a_vec,sen_b_vec):
        vector_a=np.mat(sen_a_vec)
        vector_b=np.mat(sen_b_vec)
        num=float(vector_a*vector_b.T)
        denom=np.linalg.norm(vector_a)*np.linalg.norm(vector_b)
        cos=num/denom
        return cos

if __name__=='__main__':
    
    #
    condinates= [
    "光泉鮮豆漿",
    "（好５）蔓越莓綜合果汁",
    "義美無加糖厚濃高纖黑豆奶",
    "大吸館寒天冬瓜檸檬ＱＱ",
    "咖啡伴黑糖奶茶",
    "統一陽光低糖高纖豆漿",
    "冷泡茶冷萃綠茶",
    "原萃冷萃金萱烏龍",
    "原萃凍頂青茶",
    "ＵＣＣ藍山克里曼綜合黑咖啡",
    "愛之味分解茶",
    "（選）愛之味沖繩島黑八寶禮盒",
    "三矢不知火柑橘蘇打",
    "純喫茶檸檬紅茶６５０ｍｌ",
    "鮮摘果園芭樂綜合果汁",
    "黑丸仙草甘茶",
    "貝納頌經典榛果風味拿鐵",
    "ＦＭＣ紅拿鐵",
    "小文輕烏龍奶",
    "每朝健康無糖熟藏紅茶",
    "烏龍綠茶",
    "泰山綠豆椰果",
    "蜜香歐蕾",
    "光泉黑芝麻鮮豆漿",
    "四季春青茶",
    "橘子葡萄柚風味飲",
    "黑糖紅玉薑茶（溫罐）",
    "伯朗曼特寧咖啡",
    "Ｃ＆Ｃ乳酸菌氣泡飲",
    "可口可樂蘋果口味",
    "Ｃｈｅｅｒｓ黃金柚氣泡水",
    "茉莉茶園茉香柚茶",
    "鮮榨蘋果汁",
    "左岸咖啡館昂列咖啡",
    "純萃喝重乳拿鐵",
    "義美古早傳統豆奶",
    "光泉燕麥高纖豆漿",
    "一日水果１００％蘋果汁",
    "伊藤園濃味綠茶",
    "貝納頌經典黑咖啡",
    "職人無糖冰咖啡９１０",
    "義美古早傳統無糖豆奶",
    "古早味紅茶",
    "純萃喝綠茶歐蕾",
    "一日蔬果１００％蔬果汁",
    "ＦＭＣ金萱二十七",
    "ＷＯＮＤＡ咖啡歐蕾",
    "雀巢雪梨茶",
    "伯朗冷萃無糖拿鐵",
    "寶礦力水得ｉｏｎｗａｔｅｒ",
    "蠻牛能量飲料",
    "健酪含鈣飲料",
    "台灣農林日月紅茶",
    "ＦＭＣ荔枝蘋果烏龍茶",
    "波蜜蔬果汁低卡",
    "貝納頌鑑賞級極品咖啡",
    "貝納頌經典拿鐵",
    "義美古早傳統無糖豆奶１Ｌ",
    "立頓原味奶茶",
    "珍煮丹黑糖鮮奶茶",
    "純萃喝紅茶歐蕾",
    "雙倍奶茶",
    "喬亞滴濾無糖黑咖啡",
    "藍山咖啡（６入）",
    "味丹冬瓜茶",
    "午后時光重乳可可奶茶",
    "仙草蜜夏季限定版",
    "飲冰室茶集綠奶茶",
    "黑丸仙草奶茶",
    "原萃日式焙茶",
    "原萃冷萃日式深蒸綠茶",
    "伯朗咖啡禮盒",
    "藍山咖啡禮盒",
    "三矢甘王草莓蘇打",
    "三矢海鹽蘇打",
    "光泉巧克力牛奶ＴＰ",
    "舒味思伯爵紅茶風味氣泡水",
    "芒果冰茶",
    "波蜜果菜汁",
    "ＦＭＣ楊枝甘露",
    "ＦＭＣ鮮榨金鑽鳳梨原汁",
    "午后時光嚴選曼特寧咖啡",
    "光泉薏仁糙米漿",
    "ＦＭＣ尼爾吉里藍山莊園紅茶",
    "義美古早傳統豆奶１Ｌ",
    "（選）悅氏礦泉茶品綠茶２Ｌ",
    "義美低糖高纖全豆豆奶",
    "檸檬蜂蜜水",
    "蜂蜜黑木耳露",
    "光泉無加糖濃豆漿",
    "伯朗冷萃無糖黑咖啡",
    "激浪冰晶檸檬風味汽水",
    "可口可樂巧克力咖啡汽水",
    "掠奪者能量飲料",
    "Ｃｈｅｅｒｓ檸檬氣泡水",
    "芭樂檸檬青茶",
    "純喫茶紅茶６５０ｍｌ", 
    "ＦＭＣ綠拿鐵",
    "職人加糖冰咖啡９１０",
    "光泉無加糖黑豆漿"    
    ]
    sentence_a='冰咖啡'
    bert_client=SimilarModel()
    max_cos_similar=0
    most_similar_sentence=''
    count=-1
    list_vec=[]
    list_name=[]
    
    #逐項轉向量
    for sentence_b in condinates:
        count=count+1
        sentence_a_vec=bert_client.get_sentence_vec(sentence_a)
        sentence_b_vec=bert_client.get_sentence_vec(sentence_b)
        cos_similar=bert_client.cos_similar(sentence_a_vec,sentence_b_vec)
        list_vec.append(cos_similar)
        list_name.append(condinates[count])
        print(cos_similar,condinates[count])
        
        #比大小
        if cos_similar>max_cos_similar:
            max_cos_similar=cos_similar
            most_similar_sentence=sentence_b
    print("-----------------------------------------------------------------------------------------------")
    print('與「'+sentence_a+'」最相近的產品:',most_similar_sentence,max_cos_similar)
    print("-----------------------------------------------------------------------------------------------")
    bert_client.close_bert()

#df sort
dict_df={"list_vec":list_vec,
         "list_name":list_name
        }
data=DataFrame(dict_df)
sult=data.sort_values(by=['list_vec'],ascending=False)
sult = sult.reset_index(drop=True) #reset df index

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(sult)
# Out:
# 0.8510425597952905 光泉鮮豆漿
# 0.8405989436817014 （好５）蔓越莓綜合果汁
# 0.8166138840122512 義美無加糖厚濃高纖黑豆奶
# 0.8392571235873889 大吸館寒天冬瓜檸檬ＱＱ
# 0.9086584003147149 咖啡伴黑糖奶茶
# 0.8176699339993789 統一陽光低糖高纖豆漿
# 0.8688643923505474 冷泡茶冷萃綠茶
# 0.8188184366375734 原萃冷萃金萱烏龍
# 0.8395733120666223 原萃凍頂青茶
# 0.8673167243870514 ＵＣＣ藍山克里曼綜合黑咖啡
# 0.8477591044793978 愛之味分解茶
# 0.7932029799816879 （選）愛之味沖繩島黑八寶禮盒
# 0.8147305381169381 三矢不知火柑橘蘇打
# 0.8219104004010441 純喫茶檸檬紅茶６５０ｍｌ
# 0.827796683950169 鮮摘果園芭樂綜合果汁
# 0.8343080406893001 黑丸仙草甘茶
# 0.8348825852740767 貝納頌經典榛果風味拿鐵
# 0.8573629482640344 ＦＭＣ紅拿鐵
# 0.8666576092819146 小文輕烏龍奶
# 0.8368572431543999 每朝健康無糖熟藏紅茶
# 0.871888573167606 烏龍綠茶
# 0.8255438775505807 泰山綠豆椰果
# 0.8467952648787196 蜜香歐蕾
# 0.8472215532410515 光泉黑芝麻鮮豆漿
# 0.8530406887233626 四季春青茶
# 0.8302138841231579 橘子葡萄柚風味飲
# 0.8387609161356099 黑糖紅玉薑茶（溫罐）
# 0.868744705895295 伯朗曼特寧咖啡
# 0.7967807680941228 Ｃ＆Ｃ乳酸菌氣泡飲
# 0.8037241786296909 可口可樂蘋果口味
# 0.7944072153228164 Ｃｈｅｅｒｓ黃金柚氣泡水
# 0.8222885685428782 茉莉茶園茉香柚茶
# 0.871558961784676 鮮榨蘋果汁
# ...

# %% [markdown]
# <h1><center>BM25</center></h1>

# %%
import jieba
from rank_bm25 import BM25Okapi
corpus = [
    "光泉鮮豆漿",
    "（好５）蔓越莓綜合果汁",
    "義美無加糖厚濃高纖黑豆奶",
    "大吸館寒天冬瓜檸檬ＱＱ",
    "咖啡伴黑糖奶茶",
    "統一陽光低糖高纖豆漿",
    "冷泡茶冷萃綠茶",
    "原萃冷萃金萱烏龍",
    "原萃凍頂青茶",
    "ＵＣＣ藍山克里曼綜合黑咖啡",
    "愛之味分解茶",
    "（選）愛之味沖繩島黑八寶禮盒",
    "三矢不知火柑橘蘇打",
    "純喫茶檸檬紅茶６５０ｍｌ",
    "鮮摘果園芭樂綜合果汁",
    "黑丸仙草甘茶",
    "貝納頌經典榛果風味拿鐵",
    "ＦＭＣ紅拿鐵",
    "小文輕烏龍奶",
    "每朝健康無糖熟藏紅茶",
    "烏龍綠茶",
    "泰山綠豆椰果",
    "蜜香歐蕾",
    "光泉黑芝麻鮮豆漿",
    "四季春青茶",
    "橘子葡萄柚風味飲",
    "黑糖紅玉薑茶（溫罐）",
    "伯朗曼特寧咖啡",
    "Ｃ＆Ｃ乳酸菌氣泡飲",
    "可口可樂蘋果口味",
    "Ｃｈｅｅｒｓ黃金柚氣泡水",
    "茉莉茶園茉香柚茶",
    "鮮榨蘋果汁",
    "左岸咖啡館昂列咖啡",
    "純萃喝重乳拿鐵",
    "義美古早傳統豆奶",
    "光泉燕麥高纖豆漿",
    "一日水果１００％蘋果汁",
    "伊藤園濃味綠茶",
    "貝納頌經典黑咖啡",
    "職人無糖冰咖啡９１０",
    "義美古早傳統無糖豆奶",
    "古早味紅茶",
    "純萃喝綠茶歐蕾",
    "一日蔬果１００％蔬果汁",
    "ＦＭＣ金萱二十七",
    "ＷＯＮＤＡ咖啡歐蕾",
    "雀巢雪梨茶",
    "伯朗冷萃無糖拿鐵",
    "寶礦力水得ｉｏｎｗａｔｅｒ",
    "蠻牛能量飲料",
    "健酪含鈣飲料",
    "台灣農林日月紅茶",
    "ＦＭＣ荔枝蘋果烏龍茶",
    "波蜜蔬果汁低卡",
    "貝納頌鑑賞級極品咖啡",
    "貝納頌經典拿鐵",
    "義美古早傳統無糖豆奶１Ｌ",
    "立頓原味奶茶",
    "珍煮丹黑糖鮮奶茶",
    "純萃喝紅茶歐蕾",
    "雙倍奶茶",
    "喬亞滴濾無糖黑咖啡",
    "藍山咖啡（６入）",
    "味丹冬瓜茶",
    "午后時光重乳可可奶茶",
    "仙草蜜夏季限定版",
    "飲冰室茶集綠奶茶",
    "黑丸仙草奶茶",
    "原萃日式焙茶",
    "原萃冷萃日式深蒸綠茶",
    "伯朗咖啡禮盒",
    "藍山咖啡禮盒",
    "三矢甘王草莓蘇打",
    "三矢海鹽蘇打",
    "光泉巧克力牛奶ＴＰ",
    "舒味思伯爵紅茶風味氣泡水",
    "芒果冰茶",
    "波蜜果菜汁",
    "ＦＭＣ楊枝甘露",
    "ＦＭＣ鮮榨金鑽鳳梨原汁",
    "午后時光嚴選曼特寧咖啡",
    "光泉薏仁糙米漿",
    "ＦＭＣ尼爾吉里藍山莊園紅茶",
    "義美古早傳統豆奶１Ｌ",
    "（選）悅氏礦泉茶品綠茶２Ｌ",
    "義美低糖高纖全豆豆奶",
    "檸檬蜂蜜水",
    "蜂蜜黑木耳露",
    "光泉無加糖濃豆漿",
    "伯朗冷萃無糖黑咖啡",
    "激浪冰晶檸檬風味汽水",
    "可口可樂巧克力咖啡汽水",
    "掠奪者能量飲料",
    "Ｃｈｅｅｒｓ檸檬氣泡水",
    "芭樂檸檬青茶",
    "純喫茶紅茶６５０ｍｌ",
    "ＦＭＣ綠拿鐵",
    "職人加糖冰咖啡９１０",
    "光泉無加糖黑豆漿"   
]
tokenized_corpus = [list(jieba.cut(doc)) for doc in corpus]
bm25 = BM25Okapi(tokenized_corpus)

query = "冰咖啡"

tokenized_query = list(jieba.cut(query))
doc_scores = bm25.get_scores(tokenized_query)
top1 = bm25.get_top_n(tokenized_query,corpus,n=1)

# print("斷詞結果:",tokenized_corpus)

list_doc_scores = list(doc_scores)
list_corpus = list(corpus)

#df sort
dict_df2={"doc_scores":list_doc_scores,
         "corpu":list_corpus
        }
data2=DataFrame(dict_df2)
sult2=data2.sort_values(by=['doc_scores'],ascending=False)
sult2 = sult2.reset_index(drop=True) #reset df index

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print("-------------------------------------------------------------------------------------------------------------------------")
    print('與「'+query+'」最相近的產品:',top1,sult2['doc_scores'].max())
    print("-------------------------------------------------------------------------------------------------------------------------")
    print(sult2)
# Out:
# -------------------------------------------------------------------------------------------------------------------------
# 與「冰咖啡」最相近的產品: ['職人加糖冰咖啡９１０'] 4.349370140867352
# -------------------------------------------------------------------------------------------------------------------------
#     doc_scores           corpu
# 0     4.349370      職人加糖冰咖啡９１０
# 1     4.349370      職人無糖冰咖啡９１０
# 2     1.950937          藍山咖啡禮盒
# 3     1.950937          伯朗咖啡禮盒
# 4     1.750727         咖啡伴黑糖奶茶
# 5     1.750727         伯朗曼特寧咖啡
# 6     1.750727       左岸咖啡館昂列咖啡
# 7     1.750727        貝納頌經典黑咖啡
# 8     1.750727     可口可樂巧克力咖啡汽水
# 9     1.750727       喬亞滴濾無糖黑咖啡
# 10    1.587785       伯朗冷萃無糖黑咖啡
# 11    1.587785     午后時光嚴選曼特寧咖啡
# 12    1.587785      貝納頌鑑賞級極品咖啡
# 13    1.452590        藍山咖啡（６入）
# 14    1.338612       ＷＯＮＤＡ咖啡歐蕾
# 15    1.157037   ＵＣＣ藍山克里曼綜合黑咖啡
# 16    0.000000          黑丸仙草奶茶
# 17    0.000000         貝納頌經典拿鐵
# 18    0.000000    義美古早傳統無糖豆奶１Ｌ
# 19    0.000000          立頓原味奶茶
# ...

# %% [markdown]
# <h1><center>萊文斯坦距離 (Levenshtein distance)</center></h1>

# %%
import distance

def edit_distance(s1, s2):
    return distance.levenshtein(s1, s2)

strings = [
    '職人加糖冰咖啡９１０',
    '職人無糖冰咖啡９１０',
    '左岸咖啡館昂列咖啡',
    '藍山咖啡禮盒',
    '伯朗咖啡禮盒',
    '喬亞滴濾無糖黑咖啡',
    '伯朗曼特寧咖啡',
    '貝納頌經典黑咖啡',
    '貝納頌鑑賞級極品咖啡',
    '咖啡伴黑糖奶茶',
    '可口可樂巧克力咖啡汽水',
    '伯朗冷萃無糖黑咖啡',
    '午后時光嚴選曼特寧咖啡',
    '藍山咖啡（６入）',
    'ＷＯＮＤＡ咖啡歐蕾',
    'ＵＣＣ藍山克里曼綜合黑咖啡'
]

target = '冰咖啡'

i=0
for i in range(10):
    i=i+1
    results = list(filter(lambda x: edit_distance(x, target) <= i, strings))
    if(len(results)>9):
        print("step",i,results)
        break
    else:
        print("step",i,"未達top10")
        continue
        
#df sort
dict_df0={
         "name":results
        }
data0=DataFrame(dict_df0)
sult0=data0

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print("-------------------------------------------------------------------------------------------------------------------------")
    print('與「'+target+'」最相近的產品:',sult0['name'][0])
    print("-------------------------------------------------------------------------------------------------------------------------")
    print(sult0)
# Out:
# step 1 未達top10
# step 2 未達top10
# step 3 未達top10
# step 4 未達top10
# step 5 未達top10
# step 6 未達top10
# step 7 ['職人加糖冰咖啡９１０', '職人無糖冰咖啡９１０', '左岸咖啡館昂列咖啡', '藍山咖啡禮盒', '伯朗咖啡禮盒', '喬亞滴濾無糖黑咖啡', '伯朗曼特寧咖啡', '貝納頌經典黑咖啡', '咖啡伴黑糖奶茶', '伯朗冷萃無糖黑咖啡', '藍山咖啡（６入）', 'ＷＯＮＤＡ咖啡歐蕾']
# -------------------------------------------------------------------------------------------------------------------------
# 與「冰咖啡」最相近的產品: 職人加糖冰咖啡９１０
# -------------------------------------------------------------------------------------------------------------------------
#           name
# 0   職人加糖冰咖啡９１０
# 1   職人無糖冰咖啡９１０
# 2    左岸咖啡館昂列咖啡
# 3       藍山咖啡禮盒
# 4       伯朗咖啡禮盒
# 5    喬亞滴濾無糖黑咖啡
# 6      伯朗曼特寧咖啡
# 7     貝納頌經典黑咖啡
# 8      咖啡伴黑糖奶茶
# 9    伯朗冷萃無糖黑咖啡
# 10    藍山咖啡（６入）
# 11   ＷＯＮＤＡ咖啡歐蕾

# %% [markdown]
# <h1><center>雅卡爾相似係數（Jaccard similarity coefficient）</center></h1>

# %%
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

def jaccard_similarity(s1, s2):
    def add_space(s):
        return ' '.join(list(s))
    
    # 將字中間加入空格
    s1, s2 = add_space(s1), add_space(s2)
    # 轉化為TF矩陣
    cv = CountVectorizer(tokenizer=lambda s: s.split())
    corpus = [s1, s2]
    vectors = cv.fit_transform(corpus).toarray()
    # 求交集
    numerator = np.sum(np.min(vectors, axis=0))
    # 求聯集
    denominator = np.sum(np.max(vectors, axis=0))
    # 計算傑卡德係數
    return 1.0 * numerator / denominator


s1  = [
    '職人加糖冰咖啡９１０',
    '職人無糖冰咖啡９１０',
    '左岸咖啡館昂列咖啡',
    '藍山咖啡禮盒',
    '伯朗咖啡禮盒',
    '喬亞滴濾無糖黑咖啡',
    '伯朗曼特寧咖啡',
    '貝納頌經典黑咖啡',
    '貝納頌鑑賞級極品咖啡',
    '咖啡伴黑糖奶茶',
    '可口可樂巧克力咖啡汽水',
    '伯朗冷萃無糖黑咖啡',
    '午后時光嚴選曼特寧咖啡',
    '藍山咖啡（６入）',
    'ＷＯＮＤＡ咖啡歐蕾',
    'ＵＣＣ藍山克里曼綜合黑咖啡'
]
s2 = '冰咖啡'

list_name=[]
list_similarity=[]
i=-1
for abc in s1:
    i=i+1
    Similarity=jaccard_similarity(s1[i], s2)
    list_name.append(s1[i])
    list_similarity.append(Similarity)

#df sort
dict_df3={"Similarity":list_similarity,
         "name":list_name
        }
data3=DataFrame(dict_df3)
sult3=data3.sort_values(by=['Similarity'],ascending=False)
sult3 = sult3.reset_index(drop=True) #reset df index

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print("-------------------------------------------------------------------------------------------------------------------------")
    print('與「'+s2+'」最相近的產品:',sult3['name'][0],"Similarity:",sult3['Similarity'].max())
    print("-------------------------------------------------------------------------------------------------------------------------")
    print(sult3)
# Out:
# -------------------------------------------------------------------------------------------------------------------------
# 與「冰咖啡」最相近的產品: 職人加糖冰咖啡９１０ Similarity: 0.3
# -------------------------------------------------------------------------------------------------------------------------
#     Similarity           name
# 0     0.300000     職人加糖冰咖啡９１０
# 1     0.300000     職人無糖冰咖啡９１０
# 2     0.285714         藍山咖啡禮盒
# 3     0.285714         伯朗咖啡禮盒
# 4     0.250000        伯朗曼特寧咖啡
# 5     0.250000        咖啡伴黑糖奶茶
# 6     0.222222       貝納頌經典黑咖啡
# 7     0.222222       藍山咖啡（６入）
# 8     0.200000      左岸咖啡館昂列咖啡
# 9     0.200000      喬亞滴濾無糖黑咖啡
# 10    0.200000      伯朗冷萃無糖黑咖啡
# 11    0.200000      ＷＯＮＤＡ咖啡歐蕾
# 12    0.181818     貝納頌鑑賞級極品咖啡
# 13    0.166667    可口可樂巧克力咖啡汽水
# 14    0.166667    午后時光嚴選曼特寧咖啡
# 15    0.142857  ＵＣＣ藍山克里曼綜合黑咖啡

# %% [markdown]
# <h1><center>TF-IDF</center></h1>

# %%
import numpy as np
import jieba

class TF_IDF_Model(object):
    def __init__(self, documents_list):
        self.documents_list = documents_list
        self.documents_number = len(documents_list)
        self.tf = []
        self.idf = {}
        self.init()

    def init(self):
        df = {}
        for document in self.documents_list:
            temp = {}
            for word in document:
                temp[word] = temp.get(word, 0) + 1/len(document)
            self.tf.append(temp)
            for key in temp.keys():
                df[key] = df.get(key, 0) + 1
        for key, value in df.items():
            self.idf[key] = np.log(self.documents_number / (value + 1))

    def get_score(self, index, query):
        score = 0.0
        for q in query:
            if q not in self.tf[index]:
                continue
            score += self.tf[index][q] * self.idf[q]
        return score

    def get_documents_score(self, query):
        score_list = []
        for i in range(self.documents_number):
            score_list.append(self.get_score(i, query))
        return score_list

document_list = ['職人加糖冰咖啡９１０',
    '職人無糖冰咖啡９１０',
    '左岸咖啡館昂列咖啡',
    '藍山咖啡禮盒',
    '伯朗咖啡禮盒',
    '喬亞滴濾無糖黑咖啡',
    '伯朗曼特寧咖啡',
    '貝納頌經典黑咖啡',
    '貝納頌鑑賞級極品咖啡',
    '咖啡伴黑糖奶茶',
    '可口可樂巧克力咖啡汽水',
    '伯朗冷萃無糖黑咖啡',
    '午后時光嚴選曼特寧咖啡',
    '藍山咖啡（６入）',
    'ＷＯＮＤＡ咖啡歐蕾',
    'ＵＣＣ藍山克里曼綜合黑咖啡',
]

tf_idf_model = TF_IDF_Model(document_list)

query = '冰咖啡'
scores = tf_idf_model.get_documents_score(query)

#df sort
dict_df4={"Similarity":scores,
         "name":document_list
        }
data4=DataFrame(dict_df4)
sult4=data4.sort_values(by=['Similarity'],ascending=False)
sult4 = sult4.reset_index(drop=True) #reset df index

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print("-------------------------------------------------------------------------------------------------------------------------")
    print('與「'+query+'」最相近的產品:',sult4['name'][0],"Similarity:",sult4['Similarity'].max())
    print("-------------------------------------------------------------------------------------------------------------------------")
    print(sult4)
# Out:
# -------------------------------------------------------------------------------------------------------------------------
# 與「冰咖啡」最相近的產品: 職人加糖冰咖啡９１０ Similarity: 0.15527271899388018
# -------------------------------------------------------------------------------------------------------------------------
#     Similarity           name
# 0     0.155273     職人加糖冰咖啡９１０
# 1     0.155273     職人無糖冰咖啡９１０
# 2    -0.009327  ＵＣＣ藍山克里曼綜合黑咖啡
# 3    -0.011023    可口可樂巧克力咖啡汽水
# 4    -0.011023    午后時光嚴選曼特寧咖啡
# 5    -0.012125     貝納頌鑑賞級極品咖啡
# 6    -0.013472      喬亞滴濾無糖黑咖啡
# 7    -0.013472      伯朗冷萃無糖黑咖啡
# 8    -0.013472      ＷＯＮＤＡ咖啡歐蕾
# 9    -0.015156       貝納頌經典黑咖啡
# 10   -0.015156       藍山咖啡（６入）
# 11   -0.017321        伯朗曼特寧咖啡
# 12   -0.017321        咖啡伴黑糖奶茶
# 13   -0.020208         藍山咖啡禮盒
# 14   -0.020208         伯朗咖啡禮盒
# 15   -0.026944      左岸咖啡館昂列咖啡

# %% [markdown]
# <h1><center>Synonyms</center></h1>

# %%
import synonyms
str1 = [
    "光泉鮮豆漿",
    "（好５）蔓越莓綜合果汁",
    "義美無加糖厚濃高纖黑豆奶",
    "大吸館寒天冬瓜檸檬ＱＱ",
    "咖啡伴黑糖奶茶",
    "統一陽光低糖高纖豆漿",
    "冷泡茶冷萃綠茶",
    "原萃冷萃金萱烏龍",
    "原萃凍頂青茶",
    "ＵＣＣ藍山克里曼綜合黑咖啡",
    "愛之味分解茶",
    "（選）愛之味沖繩島黑八寶禮盒",
    "三矢不知火柑橘蘇打",
    "純喫茶檸檬紅茶６５０ｍｌ",
    "鮮摘果園芭樂綜合果汁",
    "黑丸仙草甘茶",
    "貝納頌經典榛果風味拿鐵",
    "ＦＭＣ紅拿鐵",
    "小文輕烏龍奶",
    "每朝健康無糖熟藏紅茶",
    "烏龍綠茶",
    "泰山綠豆椰果",
    "蜜香歐蕾",
    "光泉黑芝麻鮮豆漿",
    "四季春青茶",
    "橘子葡萄柚風味飲",
    "黑糖紅玉薑茶（溫罐）",
    "伯朗曼特寧咖啡",
    "Ｃ＆Ｃ乳酸菌氣泡飲",
    "可口可樂蘋果口味",
    "Ｃｈｅｅｒｓ黃金柚氣泡水",
    "茉莉茶園茉香柚茶",
    "鮮榨蘋果汁",
    "左岸咖啡館昂列咖啡",
    "純萃喝重乳拿鐵",
    "義美古早傳統豆奶",
    "光泉燕麥高纖豆漿",
    "一日水果１００％蘋果汁",
    "伊藤園濃味綠茶",
    "貝納頌經典黑咖啡",
    "職人無糖冰咖啡９１０",
    "義美古早傳統無糖豆奶",
    "古早味紅茶",
    "純萃喝綠茶歐蕾",
    "一日蔬果１００％蔬果汁",
    "ＦＭＣ金萱二十七",
    "ＷＯＮＤＡ咖啡歐蕾",
    "雀巢雪梨茶",
    "伯朗冷萃無糖拿鐵",
    "寶礦力水得ｉｏｎｗａｔｅｒ",
    "蠻牛能量飲料",
    "健酪含鈣飲料",
    "台灣農林日月紅茶",
    "ＦＭＣ荔枝蘋果烏龍茶",
    "波蜜蔬果汁低卡",
    "貝納頌鑑賞級極品咖啡",
    "貝納頌經典拿鐵",
    "義美古早傳統無糖豆奶１Ｌ",
    "立頓原味奶茶",
    "珍煮丹黑糖鮮奶茶",
    "純萃喝紅茶歐蕾",
    "雙倍奶茶",
    "喬亞滴濾無糖黑咖啡",
    "藍山咖啡（６入）",
    "味丹冬瓜茶",
    "午后時光重乳可可奶茶",
    "仙草蜜夏季限定版",
    "飲冰室茶集綠奶茶",
    "黑丸仙草奶茶",
    "原萃日式焙茶",
    "原萃冷萃日式深蒸綠茶",
    "伯朗咖啡禮盒",
    "藍山咖啡禮盒",
    "三矢甘王草莓蘇打",
    "三矢海鹽蘇打",
    "光泉巧克力牛奶ＴＰ",
    "舒味思伯爵紅茶風味氣泡水",
    "芒果冰茶",
    "波蜜果菜汁",
    "ＦＭＣ楊枝甘露",
    "ＦＭＣ鮮榨金鑽鳳梨原汁",
    "午后時光嚴選曼特寧咖啡",
    "光泉薏仁糙米漿",
    "ＦＭＣ尼爾吉里藍山莊園紅茶",
    "義美古早傳統豆奶１Ｌ",
    "（選）悅氏礦泉茶品綠茶２Ｌ",
    "義美低糖高纖全豆豆奶",
    "檸檬蜂蜜水",
    "蜂蜜黑木耳露",
    "光泉無加糖濃豆漿",
    "伯朗冷萃無糖黑咖啡",
    "激浪冰晶檸檬風味汽水",
    "可口可樂巧克力咖啡汽水",
    "掠奪者能量飲料",
    "Ｃｈｅｅｒｓ檸檬氣泡水",
    "芭樂檸檬青茶",
    "純喫茶紅茶６５０ｍｌ", 
    "ＦＭＣ綠拿鐵",
    "職人加糖冰咖啡９１０",
    "光泉無加糖黑豆漿"    
]
str2 = "冰咖啡"

Similarity_list=[]
name_list=[]

i=-1
for abc in str1:
    i=i+1
    r = synonyms.compare(str1[i], str2, seg=False)
    Similarity_list.append(r)
    name_list.append(str1[i])
    
dict_df5={"Similarity":Similarity_list,
         "name":name_list
        }
data5=DataFrame(dict_df5)
sult5=data5.sort_values(by=['Similarity'],ascending=False)
sult5 = sult5.reset_index(drop=True) #reset df index

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    
    print("-------------------------------------------------------------------------------------------------------------------------")
    print('與「'+str2+'」最相近的產品:',sult5['name'][0],"Similarity:",sult5['Similarity'].max())
    print("-------------------------------------------------------------------------------------------------------------------------")
    print(sult5)
# Out:
# -------------------------------------------------------------------------------------------------------------------------
# 與「冰咖啡」最相近的產品: 藍山咖啡禮盒 Similarity: 0.641
# -------------------------------------------------------------------------------------------------------------------------
#     Similarity            name
# 0        0.641          藍山咖啡禮盒
# 1        0.611          伯朗咖啡禮盒
# 2        0.580      職人加糖冰咖啡９１０
# 3        0.573      職人無糖冰咖啡９１０
# 4        0.538         伯朗曼特寧咖啡
# 5        0.503        藍山咖啡（６入）
# 6        0.473        貝納頌經典黑咖啡
# 7        0.436       喬亞滴濾無糖黑咖啡
# 8        0.431       左岸咖啡館昂列咖啡
# 9        0.427       伯朗冷萃無糖黑咖啡
# 10       0.418      貝納頌鑑賞級極品咖啡
# 11       0.412       ＷＯＮＤＡ咖啡歐蕾
# 12       0.378     可口可樂巧克力咖啡汽水
# 13       0.317     午后時光嚴選曼特寧咖啡
# 14       0.298   ＵＣＣ藍山克里曼綜合黑咖啡
# 15       0.267         咖啡伴黑糖奶茶
# 16       0.259      激浪冰晶檸檬風味汽水
# 17       0.228        飲冰室茶集綠奶茶
# 18       0.122          愛之味分解茶
# 19       0.085         純萃喝重乳拿鐵
# ...

# %% [markdown]
# <h1><center>word2vec(fasttext)</center></h1>

# %%
from gensim.models import *
from gensim.models import word2vec, fasttext
# Settings
seed = 666
sg = 0
window_size = 10
vector_size = 100
min_count = 1
workers = 8
epochs = 5
batch_words = 10000
query="冰咖啡"

# Train
train_data = word2vec.LineSentence('test2.txt')

model = fasttext.FastText(
    train_data,
    min_count=min_count,
    vector_size=vector_size,
    workers=workers,
    epochs=epochs,
    window=window_size,
    sg=sg,
    seed=seed,
    batch_words=batch_words,
)
model.save('fasttext.model')


# 加載已訓練好的模型
model = Word2Vec.load('fasttext.model')

# 加載已訓練好的模型
model = Word2Vec.load('fasttext.model')

# 計算相關詞
res2 = model.wv.most_similar(query, topn=100)  # 10个最相关的

abc=str(res2).split(',')
list1=[]
list2=[]

i=-1
for ggg in abc:
    i=i+1
    if i%2 ==0:
        list1.append(abc[i])
    else:
        list2.append(abc[i])

dict_df6={
         "Name":list1,
         "Similarity":list2
        }
data6=DataFrame(dict_df6)
sult6=data6.sort_values(by=['Similarity'],ascending=False)
sult6['Name'] = sult6['Name'].str.replace(r'[^\w\s]+', '')
sult6['Similarity'] = sult6['Similarity'].str.replace(')', '')
sult6 = sult6.reset_index(drop=True) #reset df index

with pd.option_context('display.max_rows', None, 'display.max_columns', None):    
    print("-------------------------------------------------------------------------------------------------------------------------")
    print('與「'+query+'」最相近的產品:',sult6['Name'][0],"Similarity:",sult6['Similarity'].max())
    print("-------------------------------------------------------------------------------------------------------------------------")   
    print(sult6)
# Out:
# -------------------------------------------------------------------------------------------------------------------------
# 與「冰咖啡」最相近的產品: 伯朗冷萃無糖黑咖啡 Similarity:  0.23191648721694946
# -------------------------------------------------------------------------------------------------------------------------
#               Name               Similarity
# 0        伯朗冷萃無糖黑咖啡      0.23191648721694946
# 1         伯朗冷萃無糖拿鐵      0.21828269958496094
# 2           小文輕烏龍奶      0.21066178381443024
# 3           黑丸仙草奶茶      0.19862237572669983
# 4        三矢不知火柑橘蘇打      0.18283922970294952
# 5            鮮榨蘋果汁      0.16957980394363403
# 6       統一陽光低糖高纖豆漿       0.1693173348903656
# 7          伯朗曼特寧咖啡      0.16425910592079163
# 8         原萃冷萃金萱烏龍       0.1528327465057373
# 9           蜂蜜黑木耳露       0.1473647952079773
# 10     可口可樂巧克力咖啡汽水      0.13845111429691315
# 11         光泉薏仁糙米漿        0.135745108127594
# 12           純喫茶檸檬      0.13465328514575958
# 13          芭樂檸檬青茶       0.1342916190624237
# ...

# %% [markdown]
# <h1><center>Sentence-Transformers(Sentence-SBERT)</center></h1>

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

sentences = [
    "光泉鮮豆漿",
    "（好５）蔓越莓綜合果汁",
    "義美無加糖厚濃高纖黑豆奶",
    "大吸館寒天冬瓜檸檬ＱＱ",
    "咖啡伴黑糖奶茶",
    "統一陽光低糖高纖豆漿",
    "冷泡茶冷萃綠茶",
    "原萃冷萃金萱烏龍",
    "原萃凍頂青茶",
    "ＵＣＣ藍山克里曼綜合黑咖啡",
    "愛之味分解茶",
    "（選）愛之味沖繩島黑八寶禮盒",
    "三矢不知火柑橘蘇打",
    "純喫茶檸檬紅茶６５０ｍｌ",
    "鮮摘果園芭樂綜合果汁",
    "黑丸仙草甘茶",
    "貝納頌經典榛果風味拿鐵",
    "ＦＭＣ紅拿鐵",
    "小文輕烏龍奶",
    "每朝健康無糖熟藏紅茶",
    "烏龍綠茶",
    "泰山綠豆椰果",
    "蜜香歐蕾",
    "光泉黑芝麻鮮豆漿",
    "四季春青茶",
    "橘子葡萄柚風味飲",
    "黑糖紅玉薑茶（溫罐）",
    "伯朗曼特寧咖啡",
    "Ｃ＆Ｃ乳酸菌氣泡飲",
    "可口可樂蘋果口味",
    "Ｃｈｅｅｒｓ黃金柚氣泡水",
    "茉莉茶園茉香柚茶",
    "鮮榨蘋果汁",
    "左岸咖啡館昂列咖啡",
    "純萃喝重乳拿鐵",
    "義美古早傳統豆奶",
    "光泉燕麥高纖豆漿",
    "一日水果１００％蘋果汁",
    "伊藤園濃味綠茶",
    "貝納頌經典黑咖啡",
    "職人無糖冰咖啡９１０",
    "義美古早傳統無糖豆奶",
    "古早味紅茶",
    "純萃喝綠茶歐蕾",
    "一日蔬果１００％蔬果汁",
    "ＦＭＣ金萱二十七",
    "ＷＯＮＤＡ咖啡歐蕾",
    "雀巢雪梨茶",
    "伯朗冷萃無糖拿鐵",
    "寶礦力水得ｉｏｎｗａｔｅｒ",
    "蠻牛能量飲料",
    "健酪含鈣飲料",
    "台灣農林日月紅茶",
    "ＦＭＣ荔枝蘋果烏龍茶",
    "波蜜蔬果汁低卡",
    "貝納頌鑑賞級極品咖啡",
    "貝納頌經典拿鐵",
    "義美古早傳統無糖豆奶１Ｌ",
    "立頓原味奶茶",
    "珍煮丹黑糖鮮奶茶",
    "純萃喝紅茶歐蕾",
    "雙倍奶茶",
    "喬亞滴濾無糖黑咖啡",
    "藍山咖啡（６入）",
    "味丹冬瓜茶",
    "午后時光重乳可可奶茶",
    "仙草蜜夏季限定版",
    "飲冰室茶集綠奶茶",
    "黑丸仙草奶茶",
    "原萃日式焙茶",
    "原萃冷萃日式深蒸綠茶",
    "伯朗咖啡禮盒",
    "藍山咖啡禮盒",
    "三矢甘王草莓蘇打",
    "三矢海鹽蘇打",
    "光泉巧克力牛奶ＴＰ",
    "舒味思伯爵紅茶風味氣泡水",
    "芒果冰茶",
    "波蜜果菜汁",
    "ＦＭＣ楊枝甘露",
    "ＦＭＣ鮮榨金鑽鳳梨原汁",
    "午后時光嚴選曼特寧咖啡",
    "光泉薏仁糙米漿",
    "ＦＭＣ尼爾吉里藍山莊園紅茶",
    "義美古早傳統豆奶１Ｌ",
    "（選）悅氏礦泉茶品綠茶２Ｌ",
    "義美低糖高纖全豆豆奶",
    "檸檬蜂蜜水",
    "蜂蜜黑木耳露",
    "光泉無加糖濃豆漿",
    "伯朗冷萃無糖黑咖啡",
    "激浪冰晶檸檬風味汽水",
    "可口可樂巧克力咖啡汽水",
    "掠奪者能量飲料",
    "Ｃｈｅｅｒｓ檸檬氣泡水",
    "芭樂檸檬青茶",
    "純喫茶紅茶６５０ｍｌ", 
    "ＦＭＣ綠拿鐵",
    "職人加糖冰咖啡９１０",
    "光泉無加糖黑豆漿"    
]

query=["冰咖啡"]
model_name='paraphrase-multilingual-mpnet-base-v2' #sbert官方預訓練模型 https://www.sbert.net/docs/pretrained_models.html 

model = SentenceTransformer(model_name) #load pre-model
sentence_vecs = model.encode(sentences) #向量化
query_vecs = model.encode(query)        #向量化

similarity_list=[]
Name_list=sentences

i=-1
for cde in sentence_vecs:
    i=i+1
    result=cosine_similarity( [query_vecs[0]], [sentence_vecs[i]] )
    result=result.tolist()
    similarity_list.append(result)

dict_df7={
         "Name":Name_list,
         "Similarity":similarity_list
        }

data7=DataFrame(dict_df7)
sult7=data7.sort_values(by=['Similarity'],ascending=False) #sort
sult7 = sult7.reset_index(drop=True) #reset df index

with pd.option_context('display.max_rows', None, 'display.max_columns', None):   #全展開顯示 
    print("-------------------------------------------------------------------------------------------------------------------------")
    print('與「'+str(query[0])+'」最相近的產品:',sult7['Name'][0],"Similarity:",sult7['Similarity'].max())
    print("-------------------------------------------------------------------------------------------------------------------------")   
    print(sult7)
# Out:
# -------------------------------------------------------------------------------------------------------------------------
# 與「冰咖啡」最相近的產品: 咖啡伴黑糖奶茶 Similarity: [[0.9074164628982544]]
# -------------------------------------------------------------------------------------------------------------------------
#               Name               Similarity
# 0          咖啡伴黑糖奶茶   [[0.9074164628982544]]
# 1       職人加糖冰咖啡９１０   [[0.8877902030944824]]
# 2           伯朗咖啡禮盒   [[0.8724368214607239]]
# 3          伯朗曼特寧咖啡   [[0.8680068254470825]]
# 4           藍山咖啡禮盒   [[0.8471381068229675]]
# 5      可口可樂巧克力咖啡汽水    [[0.843925416469574]]
# 6        喬亞滴濾無糖黑咖啡   [[0.8296130299568176]]
# 7        伯朗冷萃無糖黑咖啡   [[0.8294897079467773]]
# 8       職人無糖冰咖啡９１０   [[0.8289225101470947]]
# 9       貝納頌鑑賞級極品咖啡   [[0.8279337882995605]]
# 10   ＵＣＣ藍山克里曼綜合黑咖啡   [[0.8171848654747009]]
# 11        藍山咖啡（６入）   [[0.8158326148986816]]
# 12          原萃凍頂青茶   [[0.8155544400215149]]
# 13     午后時光嚴選曼特寧咖啡   [[0.8135117292404175]]
# ...
